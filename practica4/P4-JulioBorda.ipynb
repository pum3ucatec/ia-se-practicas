# %%
# Instalar e importar librerías necesarias
import nltk
import pandas as pd
import matplotlib.pyplot as plt

# Descargar el recurso 'punkt' de NLTK para tokenización
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import requests

# URL del archivo en GitHub
url = "https://raw.githubusercontent.com/andergd/separadorSilabas/master/Carroll%2C%20Lewis%20-%20Alicia%20En%20El%20Pa%C3%ADs%20De%20Las%20Maravillas.txt"

# Descargar el archivo
response = requests.get(url)
response.raise_for_status()  # Verificar que la descarga fue exitosa

# Guardar el texto en una variable
texto = response.text

# Mostrar los primeros 500 caracteres del texto para ver si se cargó correctamente
print(texto[:500])
# Out:
# LEWIS CARROLL  (1832-1898)
# ALICIA EN EL PAIS DE LAS MARAVILLAS
#
# LEWIS CARROLL, además del gran escritor que fue, era matemático, dibujante, se le considera uno de los mejores fotógrafos de su tiempo y un poeta genial. Era profesor en la universidad de Oxford. Allí conoció a la pequeña Alicia, a quien durante un paseo por el bosque, empezó a contar una historia: Las aventuras de Alicia en el País de las Maravillas, libro clave de la literatura no sólo infantil sino también para mayores, pues

# %%
import nltk

# Descargar el recurso 'punkt' que es necesario para la tokenización
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.data.path.append("/root/nltk_data")

# %%
import nltk
from nltk.tokenize import word_tokenize

# Download the necessary resources from NLTK
# The error message is suggesting you download the 'punkt_tab' data
nltk.download('punkt_tab')

# Tokenize the text
tokens = word_tokenize(texto)

# Show the first 20 tokens
print(tokens[:20])
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['LEWIS', 'CARROLL', '(', '1832-1898', ')', 'ALICIA', 'EN', 'EL', 'PAIS', 'DE', 'LAS', 'MARAVILLAS', 'LEWIS', 'CARROLL', ',', 'además', 'del', 'gran', 'escritor', 'que']

# %%
ngramas = ngrams(tokens, 2)  # 2-gramas

# %%
print(list(ngramas)[:10])
# Out:
# [('LEWIS', 'CARROLL'), ('CARROLL', '('), ('(', '1832-1898'), ('1832-1898', ')'), (')', 'ALICIA'), ('ALICIA', 'EN'), ('EN', 'EL'), ('EL', 'PAIS'), ('PAIS', 'DE'), ('DE', 'LAS')]

# %%
ngramas_3 = ngrams(tokens, 3)

# %%
print(list(ngramas_3)[:10])
# Out:
# [('LEWIS', 'CARROLL', '('), ('CARROLL', '(', '1832-1898'), ('(', '1832-1898', ')'), ('1832-1898', ')', 'ALICIA'), (')', 'ALICIA', 'EN'), ('ALICIA', 'EN', 'EL'), ('EN', 'EL', 'PAIS'), ('EL', 'PAIS', 'DE'), ('PAIS', 'DE', 'LAS'), ('DE', 'LAS', 'MARAVILLAS')]

# %%
# Gráfica de frecuencia de n-gramas

freq_ngramas = nltk.FreqDist(ngramas)
plt.bar(freq_ngramas.keys(), freq_ngramas.values())
plt.xlabel("N-gramas")
plt.ylabel("Frecuencia")
plt.title("Frecuencia de n-gramas")
plt.show()

# %%
# Gráfica de distribución de frecuencias de n-gramas
plt.hist(freq_ngramas.values(), bins=10)
plt.xlabel("Frecuencia")
plt.ylabel("Cantidad")
plt.title("Distribución de frecuencias de n-gramas")
plt.show()

# %%
# Gráfica de n-gramas más frecuentes
ngramas_más_frecuentes = freq_ngramas.most_common(10)
plt.bar([ngrama[0] for ngrama in ngramas_más_frecuentes], [ngrama[1] for ngrama in ngramas_más_frecuentes])
plt.xlabel("N-gramas más frecuentes")
plt.ylabel("Frecuencia")
plt.title("N-gramas más frecuentes")
plt.show()
